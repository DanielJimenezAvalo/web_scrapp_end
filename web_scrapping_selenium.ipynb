# %%
import requests
from bs4 import BeautifulSoup

# %%
url='https://www.latamairlines.com/pe/es/ofertas-vuelos?dataFlight=%7B%22tripTypeSelected%22%3A%7B%22label%22%3A%22Ida%20y%20Vuelta%22%2C%22value%22%3A%22RT%22%7D%2C%22cabinSelected%22%3A%7B%22label%22%3A%22Economy%22%2C%22value%22%3A%22Economy%22%7D%2C%22passengerSelected%22%3A%7B%22adultQuantity%22%3A1%2C%22childrenQuantity%22%3A0%2C%22infantQuantity%22%3A0%7D%2C%22originSelected%22%3A%7B%22id%22%3A%22LIM_PE_AIRPORT%22%2C%22name%22%3A%22J%20Chavez%20Intl.%22%2C%22city%22%3A%22Lima%22%2C%22cityIsoCode%22%3A%22LIM%22%2C%22country%22%3A%22Per%C3%BA%22%2C%22iata%22%3A%22LIM%22%2C%22latitude%22%3A-12.0219%2C%22longitude%22%3A-77.114305%2C%22timezone%22%3A-5%2C%22tz%22%3A%22America%2FLima%22%2C%22type%22%3A%22AIRPORT%22%2C%22countryAlpha2%22%3A%22PE%22%2C%22airportIataCode%22%3A%22LIM%22%7D%2C%22destinationSelected%22%3A%7B%22id%22%3A%22MIA_US_AIRPORT%22%2C%22name%22%3A%22Miami%20Intl.%22%2C%22city%22%3A%22Miami%22%2C%22cityIsoCode%22%3A%22MIA%22%2C%22country%22%3A%22Estados%20Unidos%22%2C%22iata%22%3A%22MIA%22%2C%22latitude%22%3A25.79319953918457%2C%22longitude%22%3A-80.29060363769531%2C%22timezone%22%3A-5%2C%22tz%22%3A%22America%2FNew_York%22%2C%22type%22%3A%22AIRPORT%22%2C%22countryAlpha2%22%3A%22US%22%2C%22airportIataCode%22%3A%22MIA%22%7D%2C%22dateGoSelected%22%3A%222021-09-09T17%3A00%3A00.000Z%22%2C%22dateReturnSelected%22%3A%222021-10-13T17%3A00%3A00.000Z%22%2C%22redemption%22%3Afalse%7D&sort=RECOMMENDED'

# %%
r=requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
s=BeautifulSoup(r.text, 'lxml')

# %%
print(s.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <link href="https://s.latamairlines.com/images/seo/favicon.ico" rel="shortcut icon"/>
#   <link href="https://s.latamairlines.com/images/seo/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="https://s.latamairlines.com/images/seo/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://s.latamairlines.com/images/seo/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link color="#1b0088" href="https://s.latamairlines.com/images/seo/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="#ffffff" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/>
#   <meta charset="utf-8"/>
#   <title>
#    Selección de vuelos | Compra | LATAM Airlines
#   </title>
#   <meta content="noindex,nofollow" name="robots"/>
# ...

# %%
from selenium import webdriver

# %%
#instanciamos un driver (pagina web controlada por selenium)
options=webdriver.ChromeOptions()
options.add_argument('--incognito')
driver=webdriver.Chrome(executable_path='./chromedriver', options=options)

# %%
#hacer que el navegador cargue la pagina
driver.get(url)

# %%
#extraer informacion
vuelos = driver.find_elements_by_xpath('//li[@class = "sc-jotlie gITKrb"]')
vuelos
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d4e0bfeae9213576619e2e0a3b921545", element="b991fa67-6674-46c6-b2a9-cb1c2c05ed41")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d4e0bfeae9213576619e2e0a3b921545", element="3481cc6a-2282-46c5-ade5-5f65ee61eee4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d4e0bfeae9213576619e2e0a3b921545", element="3077d493-10fa-4bdc-a02f-b8c0efa8999b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d4e0bfeae9213576619e2e0a3b921545", element="5f64ac29-d447-42a4-b444-0e26c55e6859")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d4e0bfeae9213576619e2e0a3b921545", element="f5666360-6bbe-41ab-a185-8048980376a7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d4e0bfeae9213576619e2e0a3b921545", element="50694788-9051-4fc0-b81f-df4cbe1c97c1")>,
# ...

# %%
vuelo=vuelos[3]
vuelo
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="d4e0bfeae9213576619e2e0a3b921545", element="5f64ac29-d447-42a4-b444-0e26c55e6859")>

# %%
vuelo_informaciones=vuelo.find_elements_by_xpath('.//div[@class="sc-jhaWeW jCjnWv flight-information"]/span')
vuelo_informaciones
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d4e0bfeae9213576619e2e0a3b921545", element="f0bc7b32-7343-4c52-bf1f-407330ac5b9b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d4e0bfeae9213576619e2e0a3b921545", element="b2d27b7a-29f2-4b07-a204-469529137f50")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d4e0bfeae9213576619e2e0a3b921545", element="7cf8ae6f-ba2d-4968-bd63-408234cabc54")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d4e0bfeae9213576619e2e0a3b921545", element="1b79536d-a013-4bfc-80d4-3d256d4d3efe")>]

# %%
vuelo_informaciones[0].text
# Out:
# '7:20'

# %%
vuelo_informaciones[1].text
# Out:
# 'LIM'

# %%
vuelo_informaciones[2].text
# Out:
# '6:40\n+1'

# %%
vuelo_informaciones[3].text
# Out:
# 'MIA'

# %%
#cliquear un  boton fuera de la pagina de selenium
boton_escalas = vuelo.find_element_by_xpath('.//div[@class = "sc-hkbPbT cYvLEO"]//span')

# %%
boton_escalas
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="d4e0bfeae9213576619e2e0a3b921545", element="006843bf-21c2-473a-a391-0314b5d0948a")>

# %%
boton_escalas.click()

# %%
segmentos = vuelo.find_elements_by_xpath('//div[@class="MuiDialogContent-root sc-eqIVtm blBzMp"]//section[@data-test="section-info-leg"]')

# %%
segmentos
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d4e0bfeae9213576619e2e0a3b921545", element="1c34c982-56f7-4899-824b-eaafb73d203d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d4e0bfeae9213576619e2e0a3b921545", element="87b88a6c-4a33-4281-ba76-1626fea9da1d")>]

# %%
segmento=segmentos[0]

# %%
segmento.find_element_by_xpath('.//div[@class = "iataCode"]/span').text
# Out:
# 'LIM'

# %%
segmento.find_element_by_xpath('.//div[@class = "iataCode"]/span[@class = "time"]').text
# Out:
# '7:20'

# %%
driver.find_element_by_xpath('.//div[@class = "MuiDialog-container MuiDialog-scrollPaper"]//button[@class = "MuiButtonBase-root MuiIconButton-root sc-fMiknA jtnXZL"]').click()

# %%
vuelo.click()

# %%
#la clase no sea igual a algo, si no que contenga algo
tarifas = vuelo.find_elements_by_xpath('.//div[@class="sc-kkwfeq kuvFcF"]') #//span[contains(@class,"displayAmount")]

# %%
tarifas
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d4e0bfeae9213576619e2e0a3b921545", element="1b8c055c-c601-43b8-8843-0921a0d142bf")>]

# %%
tarifas[0].text
# Out:
# 'USD 1680.11'

# %% [markdown]
# # 16. contruyendo funciones

# %% [markdown]
# # 17. construyendo informacion para unificar el scraper

# %% [markdown]
# # 18. demoras dinamicas

# %% [markdown]
# # 19. comentarios finales selenium

# %%
#tratar de evitar de usar selenium

# %%
#cerrar el navegador
driver.close()
