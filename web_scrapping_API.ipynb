# %%
url_base = 'https://api.spotify.com/v1'

# %%
ep_artist = '/artists/{artist_id}'

# %%
id_im = '6mdiAmATAx73kdxrNrnlao'

# %%
url_base + ep_artist.format( artist_id = id_im )
# Out:
# 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao'

# %%
import requests

# %%
r = requests.get(url_base + ep_artist.format( artist_id = id_im ))

# %%
r.status_code #401, no estamos autorizados a obtener ese endpoint
# Out:
# 401

# %%
r.json() #{'error': {'status': 401, 'message': 'No token provided'}}
# Out:
# {'error': {'status': 401, 'message': 'No token provided'}}

# %%
token_url = 'https://accounts.spotify.com/api/token'

# %%
params = {'grant_type':'client_credentials'}

# %%
headers = {'Authorization':'Basic Njc1MWU4MGNjODY4NDA4MjllZGI0OWVhMTYyOGZkOGY6Y2VkOGI2NGFmODYzNDVkZWE2MWRjNDc0MzVjNmU1ODE='} 
#https://www.base64encode.org/ porner el client id y el client secret

# %%
r = requests.post(token_url, data = params, headers = headers) #https://docs.python-requests.org/es/latest/index.html

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'access_token': 'BQDsKO6yxbUoWkXVgR7A7Ca64QqpBUwpIu8vXnI-ed3kvDPDpL-8QFseo9EqhW979cwbv1sApHhpgoUAvbY',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %%
token = r.json()['access_token']

# %%
header = {'Authorization':'Bearer {}'.format(token)}

# %%
r = requests.get(url_base+ep_artist.format(artist_id = id_im), headers = header)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#  'followers': {'href': None, 'total': 6509551},
#  'genres': ['album rock', 'hard rock', 'metal', 'nwobhm', 'rock'],
#  'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#  'id': '6mdiAmATAx73kdxrNrnlao',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5ebdc52c8e309e46aa8430a0fa0',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab67616100005174dc52c8e309e46aa8430a0fa0',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f178dc52c8e309e46aa8430a0fa0',
#    'width': 160}],
#  'name': 'Iron Maiden',
#  'popularity': 78,
#  'type': 'artist',
#  'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}

# %%
url_busqueda = 'https://api.spotify.com/v1/search'

# %%
search_params = {'q':'Iron+Maiden',
                'type':'artist',
                'market':'PE'}

# %%
busqueda = requests.get(url_busqueda, headers = header, params = search_params)

# %%
busqueda.status_code
# Out:
# 200

# %%
busqueda.json()
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Iron%2BMaiden&type=artist&market=PE&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'followers': {'href': None, 'total': 6509551},
#     'genres': ['album rock', 'hard rock', 'metal', 'nwobhm', 'rock'],
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebdc52c8e309e46aa8430a0fa0',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174dc52c8e309e46aa8430a0fa0',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178dc52c8e309e46aa8430a0fa0',
#       'width': 160}],
#     'name': 'Iron Maiden',
#     'popularity': 78,
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2bb97mSGnF818Xcb86ewt7'},
#     'followers': {'href': None, 'total': 1278},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2bb97mSGnF818Xcb86ewt7',
#     'id': '2bb97mSGnF818Xcb86ewt7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bdce64846a42844594e04958',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bdce64846a42844594e04958',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bdce64846a42844594e04958',
#       'width': 64}],
#     'name': 'The Iron Maidens',
#     'popularity': 7,
#     'type': 'artist',
#     'uri': 'spotify:artist:2bb97mSGnF818Xcb86ewt7'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5jtCtv88wno9jIusR82dmQ'},
#     'followers': {'href': None, 'total': 2077},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5jtCtv88wno9jIusR82dmQ',
#     'id': '5jtCtv88wno9jIusR82dmQ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733284d7422198ab622b7bfe01',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023284d7422198ab622b7bfe01',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513284d7422198ab622b7bfe01',
#       'width': 64}],
#     'name': 'The Iron Maiden',
#     'popularity': 1,
#     'type': 'artist',
#     'uri': 'spotify:artist:5jtCtv88wno9jIusR82dmQ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0VhddzEFAYbACFHu6K6btD'},
#     'followers': {'href': None, 'total': 1272},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0VhddzEFAYbACFHu6K6btD',
#     'id': '0VhddzEFAYbACFHu6K6btD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e73c1fd8a62720ff999702d9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e73c1fd8a62720ff999702d9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e73c1fd8a62720ff999702d9',
#       'width': 64}],
#     'name': 'Paul Dianno & Dennis Stratton from Iron Maiden',
#     'popularity': 8,
#     'type': 'artist',
#     'uri': 'spotify:artist:0VhddzEFAYbACFHu6K6btD'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZr3Xthgy283qC7s4tVM1'},
#     'followers': {'href': None, 'total': 402},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2YZr3Xthgy283qC7s4tVM1',
#     'id': '2YZr3Xthgy283qC7s4tVM1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fa56acad5593bff6e3ce1dbe',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fa56acad5593bff6e3ce1dbe',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fa56acad5593bff6e3ce1dbe',
#       'width': 64}],
#     'name': 'The Bolton Iron Maiden',
#     'popularity': 2,
#     'type': 'artist',
#     'uri': 'spotify:artist:2YZr3Xthgy283qC7s4tVM1'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 5}}

# %%
import pandas as pd

# %%
df = pd.DataFrame(busqueda.json()['artists']['items'])
df.head()
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/6...
# 1  {'spotify': 'https://open.spotify.com/artist/2...
# 2  {'spotify': 'https://open.spotify.com/artist/5...
# 3  {'spotify': 'https://open.spotify.com/artist/0...
# 4  {'spotify': 'https://open.spotify.com/artist/2...
#
#                           followers  \
# 0  {'href': None, 'total': 6509551}
# 1     {'href': None, 'total': 1278}
# 2     {'href': None, 'total': 2077}
# 3     {'href': None, 'total': 1272}
# 4      {'href': None, 'total': 402}
#
#                                          genres  \
# 0  [album rock, hard rock, metal, nwobhm, rock]
# 1                                            []
# 2                                            []
# 3                                            []
# 4                                            []
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/6mdiAmATAx7...  6mdiAmATAx73kdxrNrnlao
# 1  https://api.spotify.com/v1/artists/2bb97mSGnF8...  2bb97mSGnF818Xcb86ewt7
# 2  https://api.spotify.com/v1/artists/5jtCtv88wno...  5jtCtv88wno9jIusR82dmQ
# 3  https://api.spotify.com/v1/artists/0VhddzEFAYb...  0VhddzEFAYbACFHu6K6btD
# 4  https://api.spotify.com/v1/artists/2YZr3Xthgy2...  2YZr3Xthgy283qC7s4tVM1
#
#                                               images  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                                              name  popularity    type  \
# 0                                     Iron Maiden          78  artist
# 1                                The Iron Maidens           7  artist
# 2                                 The Iron Maiden           1  artist
# 3  Paul Dianno & Dennis Stratton from Iron Maiden           8  artist
# 4                          The Bolton Iron Maiden           2  artist
#
#                                      uri
# 0  spotify:artist:6mdiAmATAx73kdxrNrnlao
# 1  spotify:artist:2bb97mSGnF818Xcb86ewt7
# 2  spotify:artist:5jtCtv88wno9jIusR82dmQ
# 3  spotify:artist:0VhddzEFAYbACFHu6K6btD
# 4  spotify:artist:2YZr3Xthgy283qC7s4tVM1

# %%
df.sort_values(by = 'popularity' , ascending = False).iloc[0]
# Out:
# external_urls    {'spotify': 'https://open.spotify.com/artist/6...
# followers                         {'href': None, 'total': 6509551}
# genres                [album rock, hard rock, metal, nwobhm, rock]
# href             https://api.spotify.com/v1/artists/6mdiAmATAx7...
# id                                          6mdiAmATAx73kdxrNrnlao
# images           [{'height': 640, 'url': 'https://i.scdn.co/ima...
# name                                                   Iron Maiden
# popularity                                                      78
# type                                                        artist
# uri                          spotify:artist:6mdiAmATAx73kdxrNrnlao
# Name: 0, dtype: object

# %%
df.sort_values(by = 'popularity' , ascending = False).iloc[0]['id']
# Out:
# '6mdiAmATAx73kdxrNrnlao'

# %% [markdown]
# # 23. obteniendo la discografia

# %%
import base64

# %%
def get_token(client_id, client_secret): #para q no expire el acceso
    
    encoded = base64.b64encode( bytes( client_id + ':' + client_secret, 'utf-8'))
    
    params = {'grant_type' : 'client_credentials'}
    
    header = {'Authorization' : 'Basic ' + str(encoded, 'utf-8')}
    
    r = requests.post('https://accounts.spotify.com/api/token', headers = header, data = params)
    
    if r.status_code != 200:
        
        print( 'error en la request.', r.json() )
        
        return None
    
    print( 'Token valido por {} segundos.'.format(r.json()['expires_in']))
    
    return r.json()['access_token']

# %%
client_id = '6751e80cc86840829edb49ea1628fd8f'

# %%
client_secret = 'ced8b64af86345dea61dc47435c6e581'

# %%
token = get_token(client_id, client_secret)
# Out:
# Token valido por 3600 segundos.

# %%
token
# Out:
# 'BQAjpK4C6tfW3DJDhdTrofE1zWN651h_VZW2FXHEN91hLlU7b1IUxSyAzGjV42Gzkx57TmY1v3sY1soqUDQ'

# %%
header = {'Authorization' : 'Bearer {}'.format(token)}

# %%
id_im
# Out:
# '6mdiAmATAx73kdxrNrnlao'

# %%
#obtener los albunes de iron maiden
ep_albums = '/artists/{artist_id}/albums' #https://api.spotify.com/v1/artists/{id}/albums

# %%
url_base + ep_albums
# Out:
# 'https://api.spotify.com/v1/artists/{artist_id}/albums'

# %%
params = {'country':'PE'}

# %%
albums_im = requests.get(url_base + ep_albums.format(artist_id = id_im), headers = header, params = params)

# %%
albums_im.status_code
# Out:
# 200

# %%
albums_im.json()
# Out:
# {'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao/albums?offset=0&limit=20&include_groups=album,single,compilation,appears_on&market=PE',
#  'items': [{'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6IVkf5av5jnraZpLPszoZR'},
#    'href': 'https://api.spotify.com/v1/albums/6IVkf5av5jnraZpLPszoZR',
#    'id': '6IVkf5av5jnraZpLPszoZR',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2733dd751909cadeef54302b0d8',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e023dd751909cadeef54302b0d8',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048513dd751909cadeef54302b0d8',
#      'width': 64}],
#    'name': 'Nights of the Dead, Legacy of the Beast: Live in Mexico City',
#    'release_date': '2020-11-20',
#    'release_date_precision': 'day',
#    'total_tracks': 17,
#    'type': 'album',
#    'uri': 'spotify:album:6IVkf5av5jnraZpLPszoZR'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1Fu7kyeRtylTNaKAv6pWyy'},
#    'href': 'https://api.spotify.com/v1/albums/1Fu7kyeRtylTNaKAv6pWyy',
#    'id': '1Fu7kyeRtylTNaKAv6pWyy',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27358057301afd41e6efaa5b547',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0258057301afd41e6efaa5b547',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485158057301afd41e6efaa5b547',
#      'width': 64}],
#    'name': 'Nights of the Dead, Legacy of the Beast: Live in Mexico City',
#    'release_date': '2020-11-20',
#    'release_date_precision': 'day',
#    'total_tracks': 17,
#    'type': 'album',
#    'uri': 'spotify:album:1Fu7kyeRtylTNaKAv6pWyy'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3oFAX7PeOFbZnKiPmpUPv4'},
#    'href': 'https://api.spotify.com/v1/albums/3oFAX7PeOFbZnKiPmpUPv4',
#    'id': '3oFAX7PeOFbZnKiPmpUPv4',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f831658588b69a862c054861',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f831658588b69a862c054861',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f831658588b69a862c054861',
#      'width': 64}],
#    'name': 'The Book of Souls: Live Chapter',
#    'release_date': '2017-11-17',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:3oFAX7PeOFbZnKiPmpUPv4'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0h63qX1zO0DAJLacVY3I7x'},
#    'href': 'https://api.spotify.com/v1/albums/0h63qX1zO0DAJLacVY3I7x',
#    'id': '0h63qX1zO0DAJLacVY3I7x',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273fad10e99730fdfc964f0a3e9',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02fad10e99730fdfc964f0a3e9',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851fad10e99730fdfc964f0a3e9',
#      'width': 64}],
#    'name': 'The Book of Souls: The Live Chapter',
#    'release_date': '2017-11-17',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:0h63qX1zO0DAJLacVY3I7x'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4vSfHrq6XxVyMcJ6PguFR2'},
#    'href': 'https://api.spotify.com/v1/albums/4vSfHrq6XxVyMcJ6PguFR2',
#    'id': '4vSfHrq6XxVyMcJ6PguFR2',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273443bd0f08a60dfad2b0165e7',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02443bd0f08a60dfad2b0165e7',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851443bd0f08a60dfad2b0165e7',
#      'width': 64}],
#    'name': 'The Book of Souls',
#    'release_date': '2015-09-04',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:4vSfHrq6XxVyMcJ6PguFR2'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6QKC7ltfafdNeBZkzLdUvF'},
#    'href': 'https://api.spotify.com/v1/albums/6QKC7ltfafdNeBZkzLdUvF',
#    'id': '6QKC7ltfafdNeBZkzLdUvF',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27357c35833a6aad57a9d0583a3',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0257c35833a6aad57a9d0583a3',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485157c35833a6aad57a9d0583a3',
#      'width': 64}],
#    'name': 'The Book of Souls',
#    'release_date': '2015-09-04',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:6QKC7ltfafdNeBZkzLdUvF'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/44myoe2TKVeLrIhfcN7xVK'},
#    'href': 'https://api.spotify.com/v1/albums/44myoe2TKVeLrIhfcN7xVK',
#    'id': '44myoe2TKVeLrIhfcN7xVK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738149b74f1d337805c27a75df',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028149b74f1d337805c27a75df',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518149b74f1d337805c27a75df',
#      'width': 64}],
#    'name': "Maiden England '88 (2013 Remaster)",
#    'release_date': '2013-03-25',
#    'release_date_precision': 'day',
#    'total_tracks': 18,
#    'type': 'album',
#    'uri': 'spotify:album:44myoe2TKVeLrIhfcN7xVK'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3LymDdEISKszJqeN2z9DBI'},
#    'href': 'https://api.spotify.com/v1/albums/3LymDdEISKszJqeN2z9DBI',
#    'id': '3LymDdEISKszJqeN2z9DBI',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273d369a33bc5a2767480db8859',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02d369a33bc5a2767480db8859',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851d369a33bc5a2767480db8859',
#      'width': 64}],
#    'name': 'En Vivo!',
#    'release_date': '2012-03-26',
#    'release_date_precision': 'day',
#    'total_tracks': 17,
#    'type': 'album',
#    'uri': 'spotify:album:3LymDdEISKszJqeN2z9DBI'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2hkRvIhUnPXbUbDDim63eJ'},
#    'href': 'https://api.spotify.com/v1/albums/2hkRvIhUnPXbUbDDim63eJ',
#    'id': '2hkRvIhUnPXbUbDDim63eJ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273dd04b6f53a7a6ec8996f8f84',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02dd04b6f53a7a6ec8996f8f84',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851dd04b6f53a7a6ec8996f8f84',
#      'width': 64}],
#    'name': 'En Vivo! (Live at Estadio Nacional, Santiago)',
#    'release_date': '2012-03-23',
#    'release_date_precision': 'day',
#    'total_tracks': 17,
#    'type': 'album',
#    'uri': 'spotify:album:2hkRvIhUnPXbUbDDim63eJ'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1iPFLsjqez49QPCX9hPmIl'},
#    'href': 'https://api.spotify.com/v1/albums/1iPFLsjqez49QPCX9hPmIl',
#    'id': '1iPFLsjqez49QPCX9hPmIl',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273de107dcfae58e51bca526dcc',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02de107dcfae58e51bca526dcc',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851de107dcfae58e51bca526dcc',
#      'width': 64}],
#    'name': 'En Vivo! (Live at Estadio Nacional, Santiago)',
#    'release_date': '2012-03-23',
#    'release_date_precision': 'day',
#    'total_tracks': 17,
#    'type': 'album',
#    'uri': 'spotify:album:1iPFLsjqez49QPCX9hPmIl'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1qwuDINuttWBKVx64FiOIj'},
#    'href': 'https://api.spotify.com/v1/albums/1qwuDINuttWBKVx64FiOIj',
#    'id': '1qwuDINuttWBKVx64FiOIj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736c07316478864ef80f8878e6',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026c07316478864ef80f8878e6',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516c07316478864ef80f8878e6',
#      'width': 64}],
#    'name': 'The Final Frontier (2015 - Remaster)',
#    'release_date': '2010-08-16',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:1qwuDINuttWBKVx64FiOIj'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5owI29GbshVBbC72drceUA'},
#    'href': 'https://api.spotify.com/v1/albums/5owI29GbshVBbC72drceUA',
#    'id': '5owI29GbshVBbC72drceUA',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273267a69826bc799123ed468c6',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02267a69826bc799123ed468c6',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851267a69826bc799123ed468c6',
#      'width': 64}],
#    'name': 'The Final Frontier (Deluxe Edition)',
#    'release_date': '2010-08-13',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:5owI29GbshVBbC72drceUA'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3CE0SB7URLI49lxJcykXUi'},
#    'href': 'https://api.spotify.com/v1/albums/3CE0SB7URLI49lxJcykXUi',
#    'id': '3CE0SB7URLI49lxJcykXUi',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27339f549ad3dbd0c5383643bf2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0239f549ad3dbd0c5383643bf2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485139f549ad3dbd0c5383643bf2',
#      'width': 64}],
#    'name': 'The Final Frontier',
#    'release_date': '2010-08-13',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:3CE0SB7URLI49lxJcykXUi'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5YAfxU5OZKqAvE1GZPRQYY'},
#    'href': 'https://api.spotify.com/v1/albums/5YAfxU5OZKqAvE1GZPRQYY',
#    'id': '5YAfxU5OZKqAvE1GZPRQYY',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736afa62d8424c574900eff429',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026afa62d8424c574900eff429',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516afa62d8424c574900eff429',
#      'width': 64}],
#    'name': 'The Final Frontier (2015 Remaster)',
#    'release_date': '2010',
#    'release_date_precision': 'year',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:5YAfxU5OZKqAvE1GZPRQYY'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5nM0AuGFYzHeJSMxAkmLW9'},
#    'href': 'https://api.spotify.com/v1/albums/5nM0AuGFYzHeJSMxAkmLW9',
#    'id': '5nM0AuGFYzHeJSMxAkmLW9',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735a7f853cee3d7b3a5c06ebec',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025a7f853cee3d7b3a5c06ebec',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515a7f853cee3d7b3a5c06ebec',
#      'width': 64}],
#    'name': 'Flight 666: The Original Soundtrack (Live)',
#    'release_date': '2009-06-09',
#    'release_date_precision': 'day',
#    'total_tracks': 17,
#    'type': 'album',
#    'uri': 'spotify:album:5nM0AuGFYzHeJSMxAkmLW9'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3yTneaS0Z3xsAmCafaYjPw'},
#    'href': 'https://api.spotify.com/v1/albums/3yTneaS0Z3xsAmCafaYjPw',
#    'id': '3yTneaS0Z3xsAmCafaYjPw',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730aceddde7027ddb4fac3ed44',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020aceddde7027ddb4fac3ed44',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510aceddde7027ddb4fac3ed44',
#      'width': 64}],
#    'name': 'Flight 666: The Original Soundtrack',
#    'release_date': '2009-05-25',
#    'release_date_precision': 'day',
#    'total_tracks': 17,
#    'type': 'album',
#    'uri': 'spotify:album:3yTneaS0Z3xsAmCafaYjPw'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1gdB9kn59KSAVG5VQcjdHi'},
#    'href': 'https://api.spotify.com/v1/albums/1gdB9kn59KSAVG5VQcjdHi',
#    'id': '1gdB9kn59KSAVG5VQcjdHi',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273bcb6a3894db841b4cdc7ab2d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02bcb6a3894db841b4cdc7ab2d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851bcb6a3894db841b4cdc7ab2d',
#      'width': 64}],
#    'name': 'A Matter of Life and Death (2015 Remaster)',
#    'release_date': '2006-08-28',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:1gdB9kn59KSAVG5VQcjdHi'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6GfWgmPjUWdmjlR0qHWZj5'},
#    'href': 'https://api.spotify.com/v1/albums/6GfWgmPjUWdmjlR0qHWZj5',
#    'id': '6GfWgmPjUWdmjlR0qHWZj5',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273fefdb067e8217e65721c9203',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02fefdb067e8217e65721c9203',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851fefdb067e8217e65721c9203',
#      'width': 64}],
#    'name': 'A Matter of Life and Death (2015 - Remaster)',
#    'release_date': '2006-08-28',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:6GfWgmPjUWdmjlR0qHWZj5'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2rVdAYBUuEnciOvQRrn4YL'},
#    'href': 'https://api.spotify.com/v1/albums/2rVdAYBUuEnciOvQRrn4YL',
#    'id': '2rVdAYBUuEnciOvQRrn4YL',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2733d4b852be77402f38065b134',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e023d4b852be77402f38065b134',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048513d4b852be77402f38065b134',
#      'width': 64}],
#    'name': 'Death on the Road',
#    'release_date': '2005-08-29',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:2rVdAYBUuEnciOvQRrn4YL'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1kN3mPkY2Tg17XsbcVdiIb'},
#    'href': 'https://api.spotify.com/v1/albums/1kN3mPkY2Tg17XsbcVdiIb',
#    'id': '1kN3mPkY2Tg17XsbcVdiIb',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f891dd75b6e764b23d1232ec',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f891dd75b6e764b23d1232ec',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f891dd75b6e764b23d1232ec',
#      'width': 64}],
#    'name': 'Death on the Road',
#    'release_date': '2005-08-29',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:1kN3mPkY2Tg17XsbcVdiIb'}],
#  'limit': 20,
#  'next': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao/albums?offset=20&limit=20&include_groups=album,single,compilation,appears_on&market=PE',
#  'offset': 0,
#  'previous': None,
#  'total': 83}

# %%
albums_im.json()['items']
# Out:
# [{'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6IVkf5av5jnraZpLPszoZR'},
#   'href': 'https://api.spotify.com/v1/albums/6IVkf5av5jnraZpLPszoZR',
#   'id': '6IVkf5av5jnraZpLPszoZR',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2733dd751909cadeef54302b0d8',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e023dd751909cadeef54302b0d8',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048513dd751909cadeef54302b0d8',
#     'width': 64}],
#   'name': 'Nights of the Dead, Legacy of the Beast: Live in Mexico City',
#   'release_date': '2020-11-20',
#   'release_date_precision': 'day',
#   'total_tracks': 17,
#   'type': 'album',
#   'uri': 'spotify:album:6IVkf5av5jnraZpLPszoZR'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1Fu7kyeRtylTNaKAv6pWyy'},
#   'href': 'https://api.spotify.com/v1/albums/1Fu7kyeRtylTNaKAv6pWyy',
#   'id': '1Fu7kyeRtylTNaKAv6pWyy',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27358057301afd41e6efaa5b547',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0258057301afd41e6efaa5b547',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485158057301afd41e6efaa5b547',
#     'width': 64}],
#   'name': 'Nights of the Dead, Legacy of the Beast: Live in Mexico City',
#   'release_date': '2020-11-20',
#   'release_date_precision': 'day',
#   'total_tracks': 17,
#   'type': 'album',
#   'uri': 'spotify:album:1Fu7kyeRtylTNaKAv6pWyy'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3oFAX7PeOFbZnKiPmpUPv4'},
#   'href': 'https://api.spotify.com/v1/albums/3oFAX7PeOFbZnKiPmpUPv4',
#   'id': '3oFAX7PeOFbZnKiPmpUPv4',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f831658588b69a862c054861',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f831658588b69a862c054861',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f831658588b69a862c054861',
#     'width': 64}],
#   'name': 'The Book of Souls: Live Chapter',
#   'release_date': '2017-11-17',
#   'release_date_precision': 'day',
#   'total_tracks': 15,
#   'type': 'album',
#   'uri': 'spotify:album:3oFAX7PeOFbZnKiPmpUPv4'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0h63qX1zO0DAJLacVY3I7x'},
#   'href': 'https://api.spotify.com/v1/albums/0h63qX1zO0DAJLacVY3I7x',
#   'id': '0h63qX1zO0DAJLacVY3I7x',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273fad10e99730fdfc964f0a3e9',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02fad10e99730fdfc964f0a3e9',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851fad10e99730fdfc964f0a3e9',
#     'width': 64}],
#   'name': 'The Book of Souls: The Live Chapter',
#   'release_date': '2017-11-17',
#   'release_date_precision': 'day',
#   'total_tracks': 15,
#   'type': 'album',
#   'uri': 'spotify:album:0h63qX1zO0DAJLacVY3I7x'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4vSfHrq6XxVyMcJ6PguFR2'},
#   'href': 'https://api.spotify.com/v1/albums/4vSfHrq6XxVyMcJ6PguFR2',
#   'id': '4vSfHrq6XxVyMcJ6PguFR2',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273443bd0f08a60dfad2b0165e7',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02443bd0f08a60dfad2b0165e7',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851443bd0f08a60dfad2b0165e7',
#     'width': 64}],
#   'name': 'The Book of Souls',
#   'release_date': '2015-09-04',
#   'release_date_precision': 'day',
#   'total_tracks': 11,
#   'type': 'album',
#   'uri': 'spotify:album:4vSfHrq6XxVyMcJ6PguFR2'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6QKC7ltfafdNeBZkzLdUvF'},
#   'href': 'https://api.spotify.com/v1/albums/6QKC7ltfafdNeBZkzLdUvF',
#   'id': '6QKC7ltfafdNeBZkzLdUvF',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27357c35833a6aad57a9d0583a3',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0257c35833a6aad57a9d0583a3',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485157c35833a6aad57a9d0583a3',
#     'width': 64}],
#   'name': 'The Book of Souls',
#   'release_date': '2015-09-04',
#   'release_date_precision': 'day',
#   'total_tracks': 11,
#   'type': 'album',
#   'uri': 'spotify:album:6QKC7ltfafdNeBZkzLdUvF'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/44myoe2TKVeLrIhfcN7xVK'},
#   'href': 'https://api.spotify.com/v1/albums/44myoe2TKVeLrIhfcN7xVK',
#   'id': '44myoe2TKVeLrIhfcN7xVK',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738149b74f1d337805c27a75df',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028149b74f1d337805c27a75df',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518149b74f1d337805c27a75df',
#     'width': 64}],
#   'name': "Maiden England '88 (2013 Remaster)",
#   'release_date': '2013-03-25',
#   'release_date_precision': 'day',
#   'total_tracks': 18,
#   'type': 'album',
#   'uri': 'spotify:album:44myoe2TKVeLrIhfcN7xVK'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3LymDdEISKszJqeN2z9DBI'},
#   'href': 'https://api.spotify.com/v1/albums/3LymDdEISKszJqeN2z9DBI',
#   'id': '3LymDdEISKszJqeN2z9DBI',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273d369a33bc5a2767480db8859',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02d369a33bc5a2767480db8859',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851d369a33bc5a2767480db8859',
#     'width': 64}],
#   'name': 'En Vivo!',
#   'release_date': '2012-03-26',
#   'release_date_precision': 'day',
#   'total_tracks': 17,
#   'type': 'album',
#   'uri': 'spotify:album:3LymDdEISKszJqeN2z9DBI'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2hkRvIhUnPXbUbDDim63eJ'},
#   'href': 'https://api.spotify.com/v1/albums/2hkRvIhUnPXbUbDDim63eJ',
#   'id': '2hkRvIhUnPXbUbDDim63eJ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273dd04b6f53a7a6ec8996f8f84',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02dd04b6f53a7a6ec8996f8f84',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851dd04b6f53a7a6ec8996f8f84',
#     'width': 64}],
#   'name': 'En Vivo! (Live at Estadio Nacional, Santiago)',
#   'release_date': '2012-03-23',
#   'release_date_precision': 'day',
#   'total_tracks': 17,
#   'type': 'album',
#   'uri': 'spotify:album:2hkRvIhUnPXbUbDDim63eJ'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1iPFLsjqez49QPCX9hPmIl'},
#   'href': 'https://api.spotify.com/v1/albums/1iPFLsjqez49QPCX9hPmIl',
#   'id': '1iPFLsjqez49QPCX9hPmIl',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273de107dcfae58e51bca526dcc',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02de107dcfae58e51bca526dcc',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851de107dcfae58e51bca526dcc',
#     'width': 64}],
#   'name': 'En Vivo! (Live at Estadio Nacional, Santiago)',
#   'release_date': '2012-03-23',
#   'release_date_precision': 'day',
#   'total_tracks': 17,
#   'type': 'album',
#   'uri': 'spotify:album:1iPFLsjqez49QPCX9hPmIl'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1qwuDINuttWBKVx64FiOIj'},
#   'href': 'https://api.spotify.com/v1/albums/1qwuDINuttWBKVx64FiOIj',
#   'id': '1qwuDINuttWBKVx64FiOIj',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2736c07316478864ef80f8878e6',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e026c07316478864ef80f8878e6',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048516c07316478864ef80f8878e6',
#     'width': 64}],
#   'name': 'The Final Frontier (2015 - Remaster)',
#   'release_date': '2010-08-16',
#   'release_date_precision': 'day',
#   'total_tracks': 10,
#   'type': 'album',
#   'uri': 'spotify:album:1qwuDINuttWBKVx64FiOIj'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5owI29GbshVBbC72drceUA'},
#   'href': 'https://api.spotify.com/v1/albums/5owI29GbshVBbC72drceUA',
#   'id': '5owI29GbshVBbC72drceUA',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273267a69826bc799123ed468c6',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02267a69826bc799123ed468c6',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851267a69826bc799123ed468c6',
#     'width': 64}],
#   'name': 'The Final Frontier (Deluxe Edition)',
#   'release_date': '2010-08-13',
#   'release_date_precision': 'day',
#   'total_tracks': 10,
#   'type': 'album',
#   'uri': 'spotify:album:5owI29GbshVBbC72drceUA'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3CE0SB7URLI49lxJcykXUi'},
#   'href': 'https://api.spotify.com/v1/albums/3CE0SB7URLI49lxJcykXUi',
#   'id': '3CE0SB7URLI49lxJcykXUi',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27339f549ad3dbd0c5383643bf2',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0239f549ad3dbd0c5383643bf2',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485139f549ad3dbd0c5383643bf2',
#     'width': 64}],
#   'name': 'The Final Frontier',
#   'release_date': '2010-08-13',
#   'release_date_precision': 'day',
#   'total_tracks': 10,
#   'type': 'album',
#   'uri': 'spotify:album:3CE0SB7URLI49lxJcykXUi'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5YAfxU5OZKqAvE1GZPRQYY'},
#   'href': 'https://api.spotify.com/v1/albums/5YAfxU5OZKqAvE1GZPRQYY',
#   'id': '5YAfxU5OZKqAvE1GZPRQYY',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2736afa62d8424c574900eff429',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e026afa62d8424c574900eff429',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048516afa62d8424c574900eff429',
#     'width': 64}],
#   'name': 'The Final Frontier (2015 Remaster)',
#   'release_date': '2010',
#   'release_date_precision': 'year',
#   'total_tracks': 10,
#   'type': 'album',
#   'uri': 'spotify:album:5YAfxU5OZKqAvE1GZPRQYY'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5nM0AuGFYzHeJSMxAkmLW9'},
#   'href': 'https://api.spotify.com/v1/albums/5nM0AuGFYzHeJSMxAkmLW9',
#   'id': '5nM0AuGFYzHeJSMxAkmLW9',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2735a7f853cee3d7b3a5c06ebec',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e025a7f853cee3d7b3a5c06ebec',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048515a7f853cee3d7b3a5c06ebec',
#     'width': 64}],
#   'name': 'Flight 666: The Original Soundtrack (Live)',
#   'release_date': '2009-06-09',
#   'release_date_precision': 'day',
#   'total_tracks': 17,
#   'type': 'album',
#   'uri': 'spotify:album:5nM0AuGFYzHeJSMxAkmLW9'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3yTneaS0Z3xsAmCafaYjPw'},
#   'href': 'https://api.spotify.com/v1/albums/3yTneaS0Z3xsAmCafaYjPw',
#   'id': '3yTneaS0Z3xsAmCafaYjPw',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2730aceddde7027ddb4fac3ed44',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e020aceddde7027ddb4fac3ed44',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048510aceddde7027ddb4fac3ed44',
#     'width': 64}],
#   'name': 'Flight 666: The Original Soundtrack',
#   'release_date': '2009-05-25',
#   'release_date_precision': 'day',
#   'total_tracks': 17,
#   'type': 'album',
#   'uri': 'spotify:album:3yTneaS0Z3xsAmCafaYjPw'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1gdB9kn59KSAVG5VQcjdHi'},
#   'href': 'https://api.spotify.com/v1/albums/1gdB9kn59KSAVG5VQcjdHi',
#   'id': '1gdB9kn59KSAVG5VQcjdHi',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273bcb6a3894db841b4cdc7ab2d',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02bcb6a3894db841b4cdc7ab2d',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851bcb6a3894db841b4cdc7ab2d',
#     'width': 64}],
#   'name': 'A Matter of Life and Death (2015 Remaster)',
#   'release_date': '2006-08-28',
#   'release_date_precision': 'day',
#   'total_tracks': 10,
#   'type': 'album',
#   'uri': 'spotify:album:1gdB9kn59KSAVG5VQcjdHi'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6GfWgmPjUWdmjlR0qHWZj5'},
#   'href': 'https://api.spotify.com/v1/albums/6GfWgmPjUWdmjlR0qHWZj5',
#   'id': '6GfWgmPjUWdmjlR0qHWZj5',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273fefdb067e8217e65721c9203',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02fefdb067e8217e65721c9203',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851fefdb067e8217e65721c9203',
#     'width': 64}],
#   'name': 'A Matter of Life and Death (2015 - Remaster)',
#   'release_date': '2006-08-28',
#   'release_date_precision': 'day',
#   'total_tracks': 10,
#   'type': 'album',
#   'uri': 'spotify:album:6GfWgmPjUWdmjlR0qHWZj5'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2rVdAYBUuEnciOvQRrn4YL'},
#   'href': 'https://api.spotify.com/v1/albums/2rVdAYBUuEnciOvQRrn4YL',
#   'id': '2rVdAYBUuEnciOvQRrn4YL',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2733d4b852be77402f38065b134',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e023d4b852be77402f38065b134',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048513d4b852be77402f38065b134',
#     'width': 64}],
#   'name': 'Death on the Road',
#   'release_date': '2005-08-29',
#   'release_date_precision': 'day',
#   'total_tracks': 16,
#   'type': 'album',
#   'uri': 'spotify:album:2rVdAYBUuEnciOvQRrn4YL'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1kN3mPkY2Tg17XsbcVdiIb'},
#   'href': 'https://api.spotify.com/v1/albums/1kN3mPkY2Tg17XsbcVdiIb',
#   'id': '1kN3mPkY2Tg17XsbcVdiIb',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f891dd75b6e764b23d1232ec',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f891dd75b6e764b23d1232ec',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f891dd75b6e764b23d1232ec',
#     'width': 64}],
#   'name': 'Death on the Road',
#   'release_date': '2005-08-29',
#   'release_date_precision': 'day',
#   'total_tracks': 16,
#   'type': 'album',
#   'uri': 'spotify:album:1kN3mPkY2Tg17XsbcVdiIb'}]

# %%
lista_albums = [ ( album['id'], album['name'] ) for album in albums_im.json()['items'] ]
lista_albums
# Out:
# [('6IVkf5av5jnraZpLPszoZR',
#   'Nights of the Dead, Legacy of the Beast: Live in Mexico City'),
#  ('1Fu7kyeRtylTNaKAv6pWyy',
#   'Nights of the Dead, Legacy of the Beast: Live in Mexico City'),
#  ('3oFAX7PeOFbZnKiPmpUPv4', 'The Book of Souls: Live Chapter'),
#  ('0h63qX1zO0DAJLacVY3I7x', 'The Book of Souls: The Live Chapter'),
#  ('4vSfHrq6XxVyMcJ6PguFR2', 'The Book of Souls'),
#  ('6QKC7ltfafdNeBZkzLdUvF', 'The Book of Souls'),
#  ('44myoe2TKVeLrIhfcN7xVK', "Maiden England '88 (2013 Remaster)"),
#  ('3LymDdEISKszJqeN2z9DBI', 'En Vivo!'),
#  ('2hkRvIhUnPXbUbDDim63eJ', 'En Vivo! (Live at Estadio Nacional, Santiago)'),
#  ('1iPFLsjqez49QPCX9hPmIl', 'En Vivo! (Live at Estadio Nacional, Santiago)'),
#  ('1qwuDINuttWBKVx64FiOIj', 'The Final Frontier (2015 - Remaster)'),
#  ('5owI29GbshVBbC72drceUA', 'The Final Frontier (Deluxe Edition)'),
#  ('3CE0SB7URLI49lxJcykXUi', 'The Final Frontier'),
#  ('5YAfxU5OZKqAvE1GZPRQYY', 'The Final Frontier (2015 Remaster)'),
#  ('5nM0AuGFYzHeJSMxAkmLW9', 'Flight 666: The Original Soundtrack (Live)'),
#  ('3yTneaS0Z3xsAmCafaYjPw', 'Flight 666: The Original Soundtrack'),
#  ('1gdB9kn59KSAVG5VQcjdHi', 'A Matter of Life and Death (2015 Remaster)'),
#  ('6GfWgmPjUWdmjlR0qHWZj5', 'A Matter of Life and Death (2015 - Remaster)'),
#  ('2rVdAYBUuEnciOvQRrn4YL', 'Death on the Road'),
#  ('1kN3mPkY2Tg17XsbcVdiIb', 'Death on the Road')]

# %%
album_ep = '/albums/{album_id}'
albums_params = {'market':'PE'}

# %%
bnw_id = '1kN3mPkY2Tg17XsbcVdiIb'

# %%
bnw = requests.get( url_base + album_ep.format(album_id = bnw_id) + '/tracks', headers = header, params = params  )
bnw
# Out:
# <Response [200]>

# %%
bnw.json()['items']
# Out:
# [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'available_markets': ['US'],
#   'disc_number': 1,
#   'duration_ms': 291800,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1pvRFmAt2aC9e2VSVlvc43'},
#   'href': 'https://api.spotify.com/v1/tracks/1pvRFmAt2aC9e2VSVlvc43',
#   'id': '1pvRFmAt2aC9e2VSVlvc43',
#   'is_local': False,
#   'name': 'Wildest Dreams - Live Dortmund, Germany',
#   'preview_url': 'https://p.scdn.co/mp3-preview/b1cd79d23dd49a8333347964239bc80bb65633a6?cid=6751e80cc86840829edb49ea1628fd8f',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:1pvRFmAt2aC9e2VSVlvc43'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'available_markets': ['US'],
#   'disc_number': 1,
#   'duration_ms': 169333,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5gWupFZgYdcRVREL1G0tIQ'},
#   'href': 'https://api.spotify.com/v1/tracks/5gWupFZgYdcRVREL1G0tIQ',
#   'id': '5gWupFZgYdcRVREL1G0tIQ',
#   'is_local': False,
#   'name': 'Wrathchild - Live Dortmund, Germany',
#   'preview_url': 'https://p.scdn.co/mp3-preview/8ae978be3176793a9976599ebe6a72a6ac2395c8?cid=6751e80cc86840829edb49ea1628fd8f',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:5gWupFZgYdcRVREL1G0tIQ'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'available_markets': ['US'],
#   'disc_number': 1,
#   'duration_ms': 210293,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4SoSjkO9BhR5IykdgfQeKi'},
#   'href': 'https://api.spotify.com/v1/tracks/4SoSjkO9BhR5IykdgfQeKi',
#   'id': '4SoSjkO9BhR5IykdgfQeKi',
#   'is_local': False,
#   'name': 'Can I Play With Madness - Live Dortmund, Germany',
#   'preview_url': 'https://p.scdn.co/mp3-preview/b00cd39d52d92178479c05aafb51b8fb516dc0bf?cid=6751e80cc86840829edb49ea1628fd8f',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:4SoSjkO9BhR5IykdgfQeKi'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'available_markets': ['US'],
#   'disc_number': 1,
#   'duration_ms': 252173,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0GE8fYBt6G2GCjSa6q00o9'},
#   'href': 'https://api.spotify.com/v1/tracks/0GE8fYBt6G2GCjSa6q00o9',
#   'id': '0GE8fYBt6G2GCjSa6q00o9',
#   'is_local': False,
#   'name': 'The Trooper - Live Dortmund, Germany',
#   'preview_url': 'https://p.scdn.co/mp3-preview/8515c5d6a6abb07f8634e9d18e5c445a6b1ad890?cid=6751e80cc86840829edb49ea1628fd8f',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:0GE8fYBt6G2GCjSa6q00o9'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'available_markets': ['US'],
#   'disc_number': 1,
#   'duration_ms': 563400,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/60BURW6kNtCd7iJLMMIA16'},
#   'href': 'https://api.spotify.com/v1/tracks/60BURW6kNtCd7iJLMMIA16',
#   'id': '60BURW6kNtCd7iJLMMIA16',
#   'is_local': False,
#   'name': 'Dance of Death - Live Dortmund, Germany',
#   'preview_url': 'https://p.scdn.co/mp3-preview/736d8db868c5505e5ecca2f85bdf5e52769e1c72?cid=6751e80cc86840829edb49ea1628fd8f',
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:60BURW6kNtCd7iJLMMIA16'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'available_markets': ['US'],
#   'disc_number': 1,
#   'duration_ms': 241493,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2NPmhIUGNLyVTbRaUVv20D'},
#   'href': 'https://api.spotify.com/v1/tracks/2NPmhIUGNLyVTbRaUVv20D',
#   'id': '2NPmhIUGNLyVTbRaUVv20D',
#   'is_local': False,
#   'name': 'Rainmaker - Live Dortmund, Germany',
#   'preview_url': 'https://p.scdn.co/mp3-preview/033789972a5f8aff679deca13dbf50c6fdd9ade8?cid=6751e80cc86840829edb49ea1628fd8f',
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:2NPmhIUGNLyVTbRaUVv20D'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'available_markets': ['US'],
#   'disc_number': 1,
#   'duration_ms': 369773,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/29Nhjf8VZ4VkRwvoAnaQ8E'},
#   'href': 'https://api.spotify.com/v1/tracks/29Nhjf8VZ4VkRwvoAnaQ8E',
#   'id': '29Nhjf8VZ4VkRwvoAnaQ8E',
#   'is_local': False,
#   'name': 'Brave New World - Live Dortmund, Germany',
#   'preview_url': 'https://p.scdn.co/mp3-preview/6b1ccbc60177883e8b2aef78b9aa764e927a1229?cid=6751e80cc86840829edb49ea1628fd8f',
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:29Nhjf8VZ4VkRwvoAnaQ8E'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'available_markets': ['US'],
#   'disc_number': 1,
#   'duration_ms': 617493,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6nWRBOyYOnp7ZWq4oAp6yg'},
#   'href': 'https://api.spotify.com/v1/tracks/6nWRBOyYOnp7ZWq4oAp6yg',
#   'id': '6nWRBOyYOnp7ZWq4oAp6yg',
#   'is_local': False,
#   'name': 'Paschendale - Live Dortmund, Germany',
#   'preview_url': 'https://p.scdn.co/mp3-preview/c4cb3c362c60c0754944a470a47e035459ec49ae?cid=6751e80cc86840829edb49ea1628fd8f',
#   'track_number': 8,
#   'type': 'track',
#   'uri': 'spotify:track:6nWRBOyYOnp7ZWq4oAp6yg'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'available_markets': ['US'],
#   'disc_number': 1,
#   'duration_ms': 304173,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7H2nP4LIvAXBhPGzdWY8k9'},
#   'href': 'https://api.spotify.com/v1/tracks/7H2nP4LIvAXBhPGzdWY8k9',
#   'id': '7H2nP4LIvAXBhPGzdWY8k9',
#   'is_local': False,
#   'name': 'Lord of the Flies - Live Dortmund, Germany',
#   'preview_url': 'https://p.scdn.co/mp3-preview/930c1d8d447dac03684c676ba55a2a11e7ec643f?cid=6751e80cc86840829edb49ea1628fd8f',
#   'track_number': 9,
#   'type': 'track',
#   'uri': 'spotify:track:7H2nP4LIvAXBhPGzdWY8k9'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'available_markets': ['US'],
#   'disc_number': 2,
#   'duration_ms': 469560,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4lHxs3ZWYRNPtEqZJNbZL1'},
#   'href': 'https://api.spotify.com/v1/tracks/4lHxs3ZWYRNPtEqZJNbZL1',
#   'id': '4lHxs3ZWYRNPtEqZJNbZL1',
#   'is_local': False,
#   'name': 'No More Lies - Live Dortmund, Germany',
#   'preview_url': 'https://p.scdn.co/mp3-preview/b469b4ea33536757dcef9f4854a479a6862aef8c?cid=6751e80cc86840829edb49ea1628fd8f',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:4lHxs3ZWYRNPtEqZJNbZL1'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'available_markets': ['US'],
#   'disc_number': 2,
#   'duration_ms': 451666,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/77T8puVfT1mUU31BxSBSQT'},
#   'href': 'https://api.spotify.com/v1/tracks/77T8puVfT1mUU31BxSBSQT',
#   'id': '77T8puVfT1mUU31BxSBSQT',
#   'is_local': False,
#   'name': 'Hallowed Be Thy Name - Live Dortmund, Germany',
#   'preview_url': 'https://p.scdn.co/mp3-preview/64d2ca6bd5bc7ab8bcecf2d07ef7a1a2c4c8bd8e?cid=6751e80cc86840829edb49ea1628fd8f',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:77T8puVfT1mUU31BxSBSQT'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'available_markets': ['US'],
#   'disc_number': 2,
#   'duration_ms': 448066,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/61oZJ5T5rvMDWBU0FCDWvd'},
#   'href': 'https://api.spotify.com/v1/tracks/61oZJ5T5rvMDWBU0FCDWvd',
#   'id': '61oZJ5T5rvMDWBU0FCDWvd',
#   'is_local': False,
#   'name': 'Fear of the Dark - Live Dortmund, Germany',
#   'preview_url': 'https://p.scdn.co/mp3-preview/9a050b1d3bd78c115cb2596cc9c3471f91b6334d?cid=6751e80cc86840829edb49ea1628fd8f',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:61oZJ5T5rvMDWBU0FCDWvd'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'available_markets': ['US'],
#   'disc_number': 2,
#   'duration_ms': 290040,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/09vnvXhN5wWErjS76TTJJs'},
#   'href': 'https://api.spotify.com/v1/tracks/09vnvXhN5wWErjS76TTJJs',
#   'id': '09vnvXhN5wWErjS76TTJJs',
#   'is_local': False,
#   'name': 'Iron Maiden - Live Dortmund, Germany',
#   'preview_url': 'https://p.scdn.co/mp3-preview/e3a399f5920aeb433f87942b5f68eba9960ac036?cid=6751e80cc86840829edb49ea1628fd8f',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:09vnvXhN5wWErjS76TTJJs'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'available_markets': ['US'],
#   'disc_number': 2,
#   'duration_ms': 422666,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/619d5W3Ow6HpwL6uEenO4e'},
#   'href': 'https://api.spotify.com/v1/tracks/619d5W3Ow6HpwL6uEenO4e',
#   'id': '619d5W3Ow6HpwL6uEenO4e',
#   'is_local': False,
#   'name': 'Journeyman - Live Dortmund, Germany',
#   'preview_url': 'https://p.scdn.co/mp3-preview/7575af2821d5e29a163fe2379f1acdc1aa0b7481?cid=6751e80cc86840829edb49ea1628fd8f',
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:619d5W3Ow6HpwL6uEenO4e'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'available_markets': ['US'],
#   'disc_number': 2,
#   'duration_ms': 297533,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/08hKOgRspjQRZ7Lis1tWsT'},
#   'href': 'https://api.spotify.com/v1/tracks/08hKOgRspjQRZ7Lis1tWsT',
#   'id': '08hKOgRspjQRZ7Lis1tWsT',
#   'is_local': False,
#   'name': 'The Number of the Beast - Live Dortmund, Germany',
#   'preview_url': 'https://p.scdn.co/mp3-preview/14a2980457d3df56df9e06a16ff8ef24857118f6?cid=6751e80cc86840829edb49ea1628fd8f',
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:08hKOgRspjQRZ7Lis1tWsT'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'available_markets': ['US'],
#   'disc_number': 2,
#   'duration_ms': 264026,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/08kB4bjR2xdfcNDiMgYdzm'},
#   'href': 'https://api.spotify.com/v1/tracks/08kB4bjR2xdfcNDiMgYdzm',
#   'id': '08kB4bjR2xdfcNDiMgYdzm',
#   'is_local': False,
#   'name': 'Run to the Hills - Live Dortmund, Germany',
#   'preview_url': 'https://p.scdn.co/mp3-preview/e5df908bee56a25da051b97ec7873752f9132ccc?cid=6751e80cc86840829edb49ea1628fd8f',
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:08kB4bjR2xdfcNDiMgYdzm'}]

# %%
[ ( track['id'], track['name']) for track in bnw.json()['items']]
# Out:
# [('1pvRFmAt2aC9e2VSVlvc43', 'Wildest Dreams - Live Dortmund, Germany'),
#  ('5gWupFZgYdcRVREL1G0tIQ', 'Wrathchild - Live Dortmund, Germany'),
#  ('4SoSjkO9BhR5IykdgfQeKi',
#   'Can I Play With Madness - Live Dortmund, Germany'),
#  ('0GE8fYBt6G2GCjSa6q00o9', 'The Trooper - Live Dortmund, Germany'),
#  ('60BURW6kNtCd7iJLMMIA16', 'Dance of Death - Live Dortmund, Germany'),
#  ('2NPmhIUGNLyVTbRaUVv20D', 'Rainmaker - Live Dortmund, Germany'),
#  ('29Nhjf8VZ4VkRwvoAnaQ8E', 'Brave New World - Live Dortmund, Germany'),
#  ('6nWRBOyYOnp7ZWq4oAp6yg', 'Paschendale - Live Dortmund, Germany'),
#  ('7H2nP4LIvAXBhPGzdWY8k9', 'Lord of the Flies - Live Dortmund, Germany'),
#  ('4lHxs3ZWYRNPtEqZJNbZL1', 'No More Lies - Live Dortmund, Germany'),
#  ('77T8puVfT1mUU31BxSBSQT', 'Hallowed Be Thy Name - Live Dortmund, Germany'),
#  ('61oZJ5T5rvMDWBU0FCDWvd', 'Fear of the Dark - Live Dortmund, Germany'),
#  ('09vnvXhN5wWErjS76TTJJs', 'Iron Maiden - Live Dortmund, Germany'),
#  ('619d5W3Ow6HpwL6uEenO4e', 'Journeyman - Live Dortmund, Germany'),
#  ('08hKOgRspjQRZ7Lis1tWsT',
#   'The Number of the Beast - Live Dortmund, Germany'),
#  ('08kB4bjR2xdfcNDiMgYdzm', 'Run to the Hills - Live Dortmund, Germany')]

# %%
def obtener_discografia(artist_id, token, return_name = False, page_limit = 50, country = None ):
    
    url = f'https://api.spotify.com/v1/artists/{artist_id}/albums'
    
    header = {'Authorization' : f'Bearer{token}'}
    
    params = {'limit' : page_limit,
              'offset' : 0,
              'country' : country
             }
    
    lista = []
    
    r = requests.get(url, params = params, headers = header)
    
    if r.status_code != 200:
        
        print('error en la request.', r.json())
        
        return None
    
    if return_name:
        
        lista += [ ( item['id'], item['name'] ) for item in r.json()['items'] ]
        
    else:
        
        lista += [ item['id'] for item in r.json()['items']]
        
    while r.json()['next']:
        
        r = requests.get(r.json()['next'], headers = header)
        
        if return_name:
        
            lista += [ ( item['id'], item['name'] ) for item in r.json()['items'] ]
        
        else:
        
            lista += [ item['id'] for item in r.json()['items']]
            
    return lista

# %%
obtener_discografia('6mdiAmATAx73kdxrNrnlao', token, return_name = False, page_limit = 50, country = None )
# Out:
# error en la request. {'error': {'status': 400, 'message': 'Only valid bearer authentication supported'}}

# %%
#https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao/albums

# %%
def obtener_tracks( album_id, token, return_name = False, page_limit = 50, market = None):
    
    url = f'GET https://api.spotify.com/v1/albums/{album_id}/tracks'
    
    header = {'Authorization' : f'Bearer{token}'}
    
    params = {'limit' : page_limit,
              'offset' : 0,
              'country' : country
             }
    
    lista = []
    
    r = requests.get(url, params = params, headers = header)
    
    if r.status_code != 200:
        
        print('error en la request.', r.json())
        
        return None
    
    if return_name:
        
        lista += [ ( item['id'], item['name'] ) for item in r.json()['items'] ]
        
    else:
        
        lista += [ item['id'] for item in r.json()['items']]
        
    while r.json()['next']:
        
        r = requests.get(r.json()['next'], headers = header)
        
        if return_name:
        
            lista += [ ( item['id'], item['name'] ) for item in r.json()['items'] ]
        
        else:
        
            lista += [ item['id'] for item in r.json()['items']]
            
    return lista

# %%
for album in obtener_discografia(id_im, token, return_name = True, country = 'PE'):
    
    print(album[1])
    
    for track in obtener_tracks(album[0], token, return_name = True, market = 'PE'):
        
        print('\t', track[1])
# Out:
# error en la request. {'error': {'status': 400, 'message': 'Only valid bearer authentication supported'}}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-090cc84efafd> in <module>
# ----> 1 for album in obtener_discografia(id_im, token, return_name = True, country = 'PE'):
#       2
#       3     print(album[1])
#       4
#       5     for track in obtener_tracks(album[0], token, return_name = True, market = 'PE'):
#
# TypeError: 'NoneType' object is not iterable

# %%
album[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-96f0ea531929> in <module>
# ----> 1 album[0]
#
# NameError: name 'album' is not defined

# %%
preview_url = 'https://p.scdn.co/mp3-preview/e5df908bee56a25da051b97ec7873752f9132ccc?cid=6751e80cc86840829edb49ea1628fd8f'

# %%
preview = requests.get(preview_url)
preview
# Out:
# <Response [200]>

# %%
import IPython.display as ipd

# %%
ipd.Audio(preview.content)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 25. Fin de proyecto + bonus
