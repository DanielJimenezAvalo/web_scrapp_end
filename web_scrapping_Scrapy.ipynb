# %%
import scrapy

# %%
class Spider12(scrapy.Spider):
    
    name = 'spider12'
    
    allowed_domains = ['pagina12.com.ar']
    
    custom_settings = { 'FEED_FORMAT' : 'json',
                      'FEED_URI' : 'resultados.json',
                      'DEPTH_LIMIT':2}
    
    start_urls = ['https://www.pagina12.com.ar/secciones/el-pais',
                 'https://www.pagina12.com.ar/secciones/economia',
                 'https://www.pagina12.com.ar/secciones/sociedad',
                 'https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos',
                 'https://www.pagina12.com.ar/secciones/deportes',
                 'https://www.pagina12.com.ar/secciones/el-mundo',
                 'https://www.pagina12.com.ar/secciones/universidad-diario']
    
    def parse(self,response):
        
        #listado de notas
        
        notas = response.xpath('//div[@class="articles-list"]//article[@class="article-item article-item--teaser"]//a/@href').getall()
        
        for nota in notas:
            
            yield response.follow(nota, callback = self.parse_nota)
        
        # link de pagina siguiente
        
        next_page = response.xpath('//a[@class="next"]/@href')
        
        if next_page is not None:
            
            yield response.follow(next_page, callback=self.parse)
            
    def parse_nota(self, response):
        
        #parseo de notas
        
        titulo = response.xpath('//div[@class="col 2-col"]/h4/text()').get()
        
        cuerpo = ''.join(response.xpath('//div[@class="col 2-col"]/p/text()').getall())
        
        yield{'url':response.url,
             'titulo':titulo,
             'cuerpo':cuerpo}

# %%
from scrapy.crawler import CrawlerProcess

# %%
process = CrawlerProcess()
process.crawl(Spider12)
process.start()
# Out:
# 2021-07-30 01:58:49 [scrapy.utils.log] INFO: Scrapy 2.5.0 started (bot: scrapybot)
# 2021-07-30 01:58:49 [scrapy.utils.log] INFO: Versions: lxml 4.6.3.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.7.0, Python 3.8.8 (default, Apr 13 2021, 19:58:26) - [GCC 7.3.0], pyOpenSSL 20.0.1 (OpenSSL 1.1.1k  25 Mar 2021), cryptography 3.4.7, Platform Linux-5.11.0-7620-generic-x86_64-with-glibc2.10
# 2021-07-30 01:58:49 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2021-07-30 01:58:49 [scrapy.crawler] INFO: Overridden settings:
# {'DEPTH_LIMIT': 2}
# 2021-07-30 01:58:50 [scrapy.extensions.telnet] INFO: Telnet Password: 05fb04136a2bb51a
# 2021-07-30 01:58:50 [py.warnings] WARNING: /home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/extensions/feedexport.py:247: ScrapyDeprecationWarning: The `FEED_URI` and `FEED_FORMAT` settings have been deprecated in favor of the `FEEDS` setting. Please see the `FEEDS` setting docs for more details
#   exporter = cls(crawler)
#
# 2021-07-30 01:58:50 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2021-07-30 01:58:50 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2021-07-30 01:58:50 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2021-07-30 01:58:50 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2021-07-30 01:58:50 [scrapy.core.engine] INFO: Spider opened
# 2021-07-30 01:58:50 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2021-07-30 01:58:50 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2021-07-30 01:58:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.pagina12.com.ar/secciones/el-mundo> (referer: None)
# 2021-07-30 01:58:50 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.pagina12.com.ar/secciones/el-mundo> (referer: None)
# Traceback (most recent call last):
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/defer.py", line 120, in iter_errback
#     yield next(it)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/python.py", line 353, in __next__
#     return next(self.data)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/python.py", line 353, in __next__
#     return next(self.data)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/referer.py", line 342, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/urllength.py", line 40, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "<ipython-input-3-60a4822ac5c9>", line 35, in parse
#     yield response.follow(next_page, callback=self.parse)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/http/response/text.py", line 167, in follow
#     raise ValueError("SelectorList is not supported")
# ValueError: SelectorList is not supported
# 2021-07-30 01:58:50 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos/30-07-2021> from <GET https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos>
# 2021-07-30 01:58:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.pagina12.com.ar/secciones/universidad-diario> (referer: None)
# 2021-07-30 01:58:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.pagina12.com.ar/secciones/sociedad> (referer: None)
# 2021-07-30 01:58:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.pagina12.com.ar/secciones/el-pais> (referer: None)
# 2021-07-30 01:58:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.pagina12.com.ar/secciones/deportes> (referer: None)
# 2021-07-30 01:58:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.pagina12.com.ar/secciones/economia> (referer: None)
# 2021-07-30 01:58:50 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.pagina12.com.ar/secciones/universidad-diario> (referer: None)
# Traceback (most recent call last):
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/defer.py", line 120, in iter_errback
#     yield next(it)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/python.py", line 353, in __next__
#     return next(self.data)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/python.py", line 353, in __next__
#     return next(self.data)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/referer.py", line 342, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/urllength.py", line 40, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "<ipython-input-3-60a4822ac5c9>", line 35, in parse
#     yield response.follow(next_page, callback=self.parse)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/http/response/text.py", line 167, in follow
#     raise ValueError("SelectorList is not supported")
# ValueError: SelectorList is not supported
# 2021-07-30 01:58:50 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.pagina12.com.ar/secciones/sociedad> (referer: None)
# Traceback (most recent call last):
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/defer.py", line 120, in iter_errback
#     yield next(it)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/python.py", line 353, in __next__
#     return next(self.data)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/python.py", line 353, in __next__
#     return next(self.data)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/referer.py", line 342, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/urllength.py", line 40, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "<ipython-input-3-60a4822ac5c9>", line 35, in parse
#     yield response.follow(next_page, callback=self.parse)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/http/response/text.py", line 167, in follow
#     raise ValueError("SelectorList is not supported")
# ValueError: SelectorList is not supported
# 2021-07-30 01:58:50 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.pagina12.com.ar/secciones/el-pais> (referer: None)
# Traceback (most recent call last):
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/defer.py", line 120, in iter_errback
#     yield next(it)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/python.py", line 353, in __next__
#     return next(self.data)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/python.py", line 353, in __next__
#     return next(self.data)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/referer.py", line 342, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/urllength.py", line 40, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "<ipython-input-3-60a4822ac5c9>", line 35, in parse
#     yield response.follow(next_page, callback=self.parse)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/http/response/text.py", line 167, in follow
#     raise ValueError("SelectorList is not supported")
# ValueError: SelectorList is not supported
# 2021-07-30 01:58:50 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.pagina12.com.ar/secciones/deportes> (referer: None)
# Traceback (most recent call last):
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/defer.py", line 120, in iter_errback
#     yield next(it)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/python.py", line 353, in __next__
#     return next(self.data)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/python.py", line 353, in __next__
#     return next(self.data)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/referer.py", line 342, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/urllength.py", line 40, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "<ipython-input-3-60a4822ac5c9>", line 35, in parse
#     yield response.follow(next_page, callback=self.parse)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/http/response/text.py", line 167, in follow
#     raise ValueError("SelectorList is not supported")
# ValueError: SelectorList is not supported
# 2021-07-30 01:58:50 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.pagina12.com.ar/secciones/economia> (referer: None)
# Traceback (most recent call last):
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/defer.py", line 120, in iter_errback
#     yield next(it)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/python.py", line 353, in __next__
#     return next(self.data)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/python.py", line 353, in __next__
#     return next(self.data)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/referer.py", line 342, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/urllength.py", line 40, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "<ipython-input-3-60a4822ac5c9>", line 35, in parse
#     yield response.follow(next_page, callback=self.parse)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/http/response/text.py", line 167, in follow
#     raise ValueError("SelectorList is not supported")
# ValueError: SelectorList is not supported
# 2021-07-30 01:58:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos/30-07-2021> (referer: None)
# 2021-07-30 01:58:51 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos/30-07-2021> (referer: None)
# Traceback (most recent call last):
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/defer.py", line 120, in iter_errback
#     yield next(it)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/python.py", line 353, in __next__
#     return next(self.data)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/utils/python.py", line 353, in __next__
#     return next(self.data)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/referer.py", line 342, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/urllength.py", line 40, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "<ipython-input-3-60a4822ac5c9>", line 35, in parse
#     yield response.follow(next_page, callback=self.parse)
#   File "/home/daniel/anaconda3/lib/python3.8/site-packages/scrapy/http/response/text.py", line 167, in follow
#     raise ValueError("SelectorList is not supported")
# ValueError: SelectorList is not supported
# 2021-07-30 01:58:51 [scrapy.core.engine] INFO: Closing spider (finished)
# 2021-07-30 01:58:51 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1980,
#  'downloader/request_count': 8,
#  'downloader/request_method_count/GET': 8,
#  'downloader/response_bytes': 123696,
#  'downloader/response_count': 8,
#  'downloader/response_status_count/200': 7,
#  'downloader/response_status_count/302': 1,
#  'elapsed_time_seconds': 1.195166,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2021, 7, 30, 6, 58, 51, 322028),
#  'httpcompression/response_bytes': 644019,
#  'httpcompression/response_count': 7,
#  'log_count/DEBUG': 8,
#  'log_count/ERROR': 7,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'memusage/max': 79933440,
#  'memusage/startup': 79933440,
#  'response_received_count': 7,
#  'scheduler/dequeued': 8,
#  'scheduler/dequeued/memory': 8,
#  'scheduler/enqueued': 8,
#  'scheduler/enqueued/memory': 8,
#  'spider_exceptions/ValueError': 7,
#  'start_time': datetime.datetime(2021, 7, 30, 6, 58, 50, 126862)}
# 2021-07-30 01:58:51 [scrapy.core.engine] INFO: Spider closed (finished)
